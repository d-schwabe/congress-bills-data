# %% [markdown]
# # Part 2a: Exploring 115th Congress
#
# I used this notebook as an initial testing ground for getting to know the vast .json files available one ach bill. I look through the patterns for just one congress, the 115th, so that I can apply what I learn to my analysis of the others.

# %%
import json
import pandas as pd
import glob
import os

# %%
# get all the folder names in 'data/115/115/bills/hr/'
bill_paths = glob.glob('data/115/115/bills/hr/' + '*' + os.path.sep)

# %%
len(bill_paths)
# Out:
# 7393

# %%
bill_paths[0:5]
# Out:
# ['data/115/115/bills/hr/hr1216/',
#  'data/115/115/bills/hr/hr4764/',
#  'data/115/115/bills/hr/hr337/',
#  'data/115/115/bills/hr/hr6033/',
#  'data/115/115/bills/hr/hr2493/']

# %%
# empty list to collect bills that passed
passed_bills = []

# loop over all the bill_paths
for bill_path in bill_paths:
    
    # there's a data.json file in every bill_path
    file_name = f'{ bill_path }/data.json'

    # read the json
    with open(file_name) as f:
        bill_json = json.load(f)
        # every bill has a status key; i only want the ones where
        # `status` is 'ENACTED:SIGNED'
        if bill_json['status'] == 'ENACTED:SIGNED':
            # append bill_path to list if it was enacted/signed
            passed_bills.append(bill_path)

# %%
len(passed_bills)
# Out:
# 284

# %%
# let's just see what one of these bills looks like in json
with open(f'{ passed_bills[0] }/data.json') as f:
    print(passed_bills[0])
    bill_json = json.load(f)
    # pretty-print 
    print(json.dumps(bill_json, indent = 4, sort_keys=True))
# Out:
# data/115/115/bills/hr/hr4300/
# {
#     "actions": [
#         {
#             "acted_at": "2017-11-08",
#             "action_code": "Intro-H",
#             "references": [],
#             "text": "Introduced in House",
#             "type": "action"
#         },
#         {
#             "acted_at": "2017-11-08",
#             "action_code": "H11100",
#             "committees": [
#                 "HSII"
#             ],
#             "references": [],
#             "status": "REFERRED",
#             "text": "Referred to the House Committee on Natural Resources.",
#             "type": "referral"
#         },
#         {
#             "acted_at": "2017-11-29",
#             "action_code": "",
#             "committees": [
#                 "HSII"
#             ],
#             "references": [],
#             "text": "Committee Consideration and Mark-up Session Held.",
#             "type": "action"
#         },
#         {
#             "acted_at": "2017-11-30",
#             "action_code": "",
#             "committees": [
#                 "HSII"
#             ],
#             "references": [],
#             "text": "Committee Consideration and Mark-up Session Held.",
#             "type": "action"
#         },
#         {
#             "acted_at": "2017-11-30",
#             "action_code": "",
#             "committees": [
#                 "HSII"
#             ],
#             "references": [],
#             "status": "REPORTED",
#             "text": "Ordered to be Reported by Unanimous Consent.",
#             "type": "calendar"
#         },
#         {
#             "acted_at": "2017-12-06",
#             "action_code": "H12200",
#             "committees": [
#                 "HSII"
#             ],
#             "links": [
#                 {
#                     "name": "H. Rept. 115-450",
#                     "url": "https://www.congress.gov/congressional-report/115th-congress/house-report/450"
#                 }
#             ],
#             "references": [],
#             "text": "Reported by the Committee on Natural Resources. H. Rept. 115-450.",
#             "type": "action"
#         },
#         {
#             "acted_at": "2017-12-06",
#             "action_code": "H12410",
#             "calendar": "Union",
#             "number": "332",
#             "references": [],
#             "text": "Placed on the Union Calendar, Calendar No. 332.",
#             "type": "calendar",
#             "under": null
#         },
#         {
#             "acted_at": "2017-12-07T17:12:59-05:00",
#             "action_code": "H30000",
#             "links": [
#                 {
#                     "name": "H9746",
#                     "url": "https://www.congress.gov/congressional-record/volume-163/house-section/page/H9746"
#                 }
#             ],
#             "references": [
#                 {
#                     "reference": "CR H9746",
#                     "type": "consideration"
#                 }
#             ],
#             "text": "Considered by unanimous consent.",
#             "type": "action"
#         },
#         {
#             "acted_at": "2017-12-07T17:12:59-05:00",
#             "action_code": "H30200",
#             "references": [],
#             "text": "Mr. Bishop (UT) asked unanimous consent to take from the Speaker's table and consider.",
#             "type": "action"
#         },
#         {
#             "acted_at": "2017-12-07T17:13:30-05:00",
#             "action_code": "H37100",
#             "how": "without objection",
#             "links": [
#                 {
#                     "name": "H9746",
#                     "url": "https://www.congress.gov/congressional-record/volume-163/house-section/page/H9746"
#                 }
#             ],
#             "references": [
#                 {
#                     "reference": "CR H9746",
#                     "type": "text"
#                 }
#             ],
#             "result": "pass",
#             "status": "PASS_OVER:HOUSE",
#             "suspension": null,
#             "text": "On passage Passed without objection.",
#             "type": "vote",
#             "vote_type": "vote",
#             "where": "h"
#         },
#         {
#             "acted_at": "2017-12-07T17:13:31-05:00",
#             "action_code": "H38310",
#             "references": [],
#             "text": "Motion to reconsider laid on the table Agreed to without objection.",
#             "type": "action"
#         },
#         {
#             "acted_at": "2017-12-11",
#             "action_code": "",
#             "committees": [
#                 "SSEG"
#             ],
#             "references": [],
#             "text": "Received in the Senate and Read twice and referred to the Committee on Energy and Natural Resources.",
#             "type": "referral"
#         },
#         {
#             "acted_at": "2018-02-14",
#             "action_code": "",
#             "committee": "Committee on Energy and Natural Resources Subcommittee on National Parks",
#             "committees": [
#                 "SSEG"
#             ],
#             "references": [],
#             "text": "Committee on Energy and Natural Resources Subcommittee on National Parks. Hearings held.",
#             "type": "hearings"
#         },
#         {
#             "acted_at": "2018-03-08",
#             "action_code": "",
#             "committees": [
#                 "SSEG"
#             ],
#             "references": [],
#             "text": "Committee on Energy and Natural Resources. Ordered to be reported without amendment favorably.",
#             "type": "calendar"
#         },
#         {
#             "acted_at": "2018-03-21",
#             "action_code": "",
#             "committee": "Energy and Natural Resources",
#             "committees": [
#                 "SSEG"
#             ],
#             "links": [
#                 {
#                     "name": "report No. 115-216",
#                     "url": "https://www.congress.gov/congressional-report/115th-congress/senate-report/216"
#                 }
#             ],
#             "references": [],
#             "text": "Committee on Energy and Natural Resources. Reported by Senator Murkowski without amendment. With written report No. 115-216.",
#             "type": "reported"
#         },
#         {
#             "acted_at": "2018-03-21",
#             "action_code": "",
#             "calendar": "Senate Legislative",
#             "number": "360",
#             "references": [],
#             "text": "Placed on Senate Legislative Calendar under General Orders. Calendar No. 360.",
#             "type": "calendar",
#             "under": "General Orders"
#         },
#         {
#             "acted_at": "2018-04-23",
#             "action_code": "",
#             "how": "by Unanimous Consent",
#             "links": [
#                 {
#                     "name": "S2354",
#                     "url": "https://www.congress.gov/congressional-record/volume-164/senate-section/page/S2354"
#                 }
#             ],
#             "references": [
#                 {
#                     "reference": "CR S2354",
#                     "type": "consideration"
#                 }
#             ],
#             "result": "pass",
#             "status": "PASSED:BILL",
#             "text": "Passed Senate without amendment by Unanimous Consent.",
#             "type": "vote",
#             "vote_type": "vote2",
#             "where": "s"
#         },
#         {
#             "acted_at": "2018-04-24",
#             "action_code": "",
#             "references": [],
#             "text": "Message on Senate action sent to the House.",
#             "type": "action"
#         },
#         {
#             "acted_at": "2018-04-25",
#             "action_code": "E20000",
#             "references": [],
#             "text": "Presented to President.",
#             "type": "topresident"
#         },
#         {
#             "acted_at": "2018-05-07",
#             "action_code": "E30000",
#             "references": [],
#             "status": "ENACTED:SIGNED",
#             "text": "Signed by President.",
#             "type": "signed"
#         },
#         {
#             "acted_at": "2018-05-07",
#             "action_code": "E40000",
#             "congress": "115",
#             "law": "public",
#             "links": [
#                 {
#                     "name": "Public Law No: 115-170",
#                     "url": "https://www.congress.gov/bill/115th-congress/house-bill/4300/text/pl"
#                 }
#             ],
#             "number": "170",
#             "references": [],
#             "text": "Became Public Law No: 115-170.",
#             "type": "enacted"
#         }
#     ],
#     "amendments": [],
#     "bill_id": "hr4300-115",
#     "bill_type": "hr",
#     "by_request": false,
#     "committee_reports": [
#         "H. Rept. 115-450",
#         "S. Rept. 115-216"
#     ],
#     "committees": [
#         {
#             "activity": [
#                 "reporting",
#                 "markup",
#                 "referral"
#             ],
#             "committee": "Senate Energy and Natural Resources",
#             "committee_id": "SSEG"
#         },
#         {
#             "activity": [
#                 "hearings"
#             ],
#             "committee": "Senate Energy and Natural Resources",
#             "committee_id": "SSEG",
#             "subcommittee": "Subcommittee on National Parks",
#             "subcommittee_id": "04"
#         },
#         {
#             "activity": [
#                 "reporting",
#                 "markup",
#                 "referral"
#             ],
#             "committee": "House Natural Resources",
#             "committee_id": "HSII"
#         }
#     ],
#     "congress": "115",
#     "cosponsors": [
#         {
#             "bioguide_id": "A000370",
#             "district": "12",
#             "name": "Adams, Alma S.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "NC",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "A000371",
#             "district": "31",
#             "name": "Aguilar, Pete",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "B001270",
#             "district": "37",
#             "name": "Bass, Karen",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "B001287",
#             "district": "7",
#             "name": "Bera, Ami",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "B001250",
#             "district": "1",
#             "name": "Bishop, Rob",
#             "original_cosponsor": true,
#             "sponsored_at": "2017-11-08",
#             "state": "UT",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "B001245",
#             "district": "0",
#             "name": "Bordallo, Madeleine Z.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "GU",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "B001227",
#             "district": "1",
#             "name": "Brady, Robert A.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "PA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "B001304",
#             "district": "4",
#             "name": "Brown, Anthony G.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "MD",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "B001285",
#             "district": "26",
#             "name": "Brownley, Julia",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-04",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "B001286",
#             "district": "17",
#             "name": "Bustos, Cheri",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "IL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001112",
#             "district": "24",
#             "name": "Carbajal, Salud O.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001109",
#             "district": "0",
#             "name": "Cheney, Liz",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "WY",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001084",
#             "district": "1",
#             "name": "Cicilline, David N.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "RI",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001077",
#             "district": "6",
#             "name": "Coffman, Mike",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-04",
#             "state": "CO",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001068",
#             "district": "9",
#             "name": "Cohen, Steve",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-30",
#             "state": "TN",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001053",
#             "district": "4",
#             "name": "Cole, Tom",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-06",
#             "state": "OK",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001094",
#             "district": "8",
#             "name": "Cook, Paul",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-01",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C000754",
#             "district": "5",
#             "name": "Cooper, Jim",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "TN",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001059",
#             "district": "16",
#             "name": "Costa, Jim",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001069",
#             "district": "2",
#             "name": "Courtney, Joe",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CT",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001111",
#             "district": "13",
#             "name": "Crist, Charlie",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "FL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "C001107",
#             "district": "26",
#             "name": "Curbelo, Carlos",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "FL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "D000191",
#             "district": "4",
#             "name": "DeFazio, Peter A.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-06",
#             "state": "OR",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "D000627",
#             "district": "10",
#             "name": "Demings, Val Butler",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "FL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "D000624",
#             "district": "12",
#             "name": "Dingell, Debbie",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-01",
#             "state": "MI",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "E000296",
#             "district": "2",
#             "name": "Evans, Dwight",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "PA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "F000462",
#             "district": "21",
#             "name": "Frankel, Lois",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "FL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "G000571",
#             "district": "2",
#             "name": "Gabbard, Tulsi",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-30",
#             "state": "HI",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "G000574",
#             "district": "7",
#             "name": "Gallego, Ruben",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "AZ",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "G000581",
#             "district": "15",
#             "name": "Gonzalez, Vicente",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "TX",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "G000546",
#             "district": "6",
#             "name": "Graves, Sam",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-04",
#             "state": "MO",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "G000553",
#             "district": "9",
#             "name": "Green, Al",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-06",
#             "state": "TX",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "G000410",
#             "district": "29",
#             "name": "Green, Gene",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "TX",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "G000551",
#             "district": "3",
#             "name": "Grijalva, Raul M.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "AZ",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "H000324",
#             "district": "20",
#             "name": "Hastings, Alcee L.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "FL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "H001038",
#             "district": "26",
#             "name": "Higgins, Brian",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-04",
#             "state": "NY",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "J000032",
#             "district": "18",
#             "name": "Jackson Lee, Sheila",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-14",
#             "state": "TX",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "J000126",
#             "district": "30",
#             "name": "Johnson, Eddie Bernice",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "TX",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "J000288",
#             "district": "4",
#             "name": "Johnson, Henry C. \"Hank,\" Jr.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "GA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "J000255",
#             "district": "3",
#             "name": "Jones, Walter B., Jr.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-14",
#             "state": "NC",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "K000009",
#             "district": "9",
#             "name": "Kaptur, Marcy",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-14",
#             "state": "OH",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "K000375",
#             "district": "9",
#             "name": "Keating, William R.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-30",
#             "state": "MA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "K000389",
#             "district": "17",
#             "name": "Khanna, Ro",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "K000380",
#             "district": "5",
#             "name": "Kildee, Daniel T.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "MI",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "K000391",
#             "district": "8",
#             "name": "Krishnamoorthi, Raja",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "IL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000578",
#             "district": "1",
#             "name": "LaMalfa, Doug",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-06",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000564",
#             "district": "5",
#             "name": "Lamborn, Doug",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "CO",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000559",
#             "district": "2",
#             "name": "Langevin, James R.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "RI",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000557",
#             "district": "1",
#             "name": "Larson, John B.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CT",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000581",
#             "district": "14",
#             "name": "Lawrence, Brenda L.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "MI",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000551",
#             "district": "13",
#             "name": "Lee, Barbara",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000287",
#             "district": "5",
#             "name": "Lewis, John",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "GA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000582",
#             "district": "33",
#             "name": "Lieu, Ted",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000563",
#             "district": "3",
#             "name": "Lipinski, Daniel",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "IL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000397",
#             "district": "19",
#             "name": "Lofgren, Zoe",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "L000579",
#             "district": "47",
#             "name": "Lowenthal, Alan S.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-06",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "M001163",
#             "district": "6",
#             "name": "Matsui, Doris O.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-04",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "M001143",
#             "district": "4",
#             "name": "McCollum, Betty",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "MN",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "M001197",
#             "district": "2",
#             "name": "McSally, Martha",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "AZ",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "M001160",
#             "district": "4",
#             "name": "Moore, Gwen",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "WI",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "M001202",
#             "district": "7",
#             "name": "Murphy, Stephanie N.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-30",
#             "state": "FL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "N000179",
#             "district": "32",
#             "name": "Napolitano, Grace F.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "N000127",
#             "district": "8",
#             "name": "Nolan, Richard M.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "MN",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "N000147",
#             "district": "0",
#             "name": "Norton, Eleanor Holmes",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-04",
#             "state": "DC",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "P000034",
#             "district": "6",
#             "name": "Pallone, Frank, Jr.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "NJ",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "P000613",
#             "district": "20",
#             "name": "Panetta, Jimmy",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "P000604",
#             "district": "10",
#             "name": "Payne, Donald M., Jr.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "NJ",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "P000593",
#             "district": "7",
#             "name": "Perlmutter, Ed",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "CO",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "R000600",
#             "district": "0",
#             "name": "Radewagen, Aumua Amata Coleman",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-14",
#             "state": "AS",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "R000606",
#             "district": "8",
#             "name": "Raskin, Jamie",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-04",
#             "state": "MD",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "R000588",
#             "district": "2",
#             "name": "Richmond, Cedric L.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "LA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "R000582",
#             "district": "1",
#             "name": "Roe, David P.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-06",
#             "state": "TN",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "R000576",
#             "district": "2",
#             "name": "Ruppersberger, C. A. Dutch",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "MD",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S001177",
#             "district": "0",
#             "name": "Sablan, Gregorio Kilili Camacho",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "MP",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S000248",
#             "district": "15",
#             "name": "Serrano, Jose E.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "NY",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S001185",
#             "district": "7",
#             "name": "Sewell, Terri A.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "AL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S001170",
#             "district": "1",
#             "name": "Shea-Porter, Carol",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "NH",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S001154",
#             "district": "9",
#             "name": "Shuster, Bill",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "PA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S001191",
#             "district": "9",
#             "name": "Sinema, Kyrsten",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "AZ",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S001165",
#             "district": "8",
#             "name": "Sires, Albio",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "NJ",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S001200",
#             "district": "9",
#             "name": "Soto, Darren",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "FL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "S001175",
#             "district": "14",
#             "name": "Speier, Jackie",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-04",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "T000460",
#             "district": "5",
#             "name": "Thompson, Mike",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "T000468",
#             "district": "1",
#             "name": "Titus, Dina",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "NV",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "T000474",
#             "district": "35",
#             "name": "Torres, Norma J.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "CA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "W000798",
#             "district": "7",
#             "name": "Walberg, Tim",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-12-05",
#             "state": "MI",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "W000822",
#             "district": "12",
#             "name": "Watson Coleman, Bonnie",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-28",
#             "state": "NJ",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "W000808",
#             "district": "24",
#             "name": "Wilson, Frederica S.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "FL",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "W000804",
#             "district": "1",
#             "name": "Wittman, Robert J.",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-30",
#             "state": "VA",
#             "title": "Rep",
#             "withdrawn_at": null
#         },
#         {
#             "bioguide_id": "Y000033",
#             "district": "0",
#             "name": "Young, Don",
#             "original_cosponsor": false,
#             "sponsored_at": "2017-11-29",
#             "state": "AK",
#             "title": "Rep",
#             "withdrawn_at": null
#         }
#     ],
#     "enacted_as": {
#         "congress": "115",
#         "law_type": "public",
#         "number": "170"
#     },
#     "history": {
#         "active": true,
#         "active_at": "2017-11-29",
#         "awaiting_signature": false,
#         "enacted": true,
#         "enacted_at": "2018-05-07",
#         "house_passage_result": "pass",
#         "house_passage_result_at": "2017-12-07T17:13:30-05:00",
#         "senate_passage_result": "pass",
#         "senate_passage_result_at": "2018-04-23",
#         "vetoed": false
#     },
#     "introduced_at": "2017-11-08",
#     "number": "4300",
#     "official_title": "To authorize Pacific Historic Parks to establish a commemorative display to honor members of the United States Armed Forces who served in the Pacific Theater of World War II, and for other purposes.",
#     "popular_title": null,
#     "related_bills": [
#         {
#             "bill_id": "s2213-115",
#             "identified_by": "House",
#             "reason": "related",
#             "type": "bill"
#         }
#     ],
#     "short_title": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act",
#     "sponsor": {
#         "bioguide_id": "H001050",
#         "district": "1",
#         "name": "Hanabusa, Colleen",
#         "state": "HI",
#         "title": "Rep",
#         "type": "person"
#     },
#     "status": "ENACTED:SIGNED",
#     "status_at": "2018-05-07",
#     "subjects": [
#         "Armed forces and national security",
#         "Conflicts and wars",
#         "Hawaii",
#         "Military facilities and property",
#         "Military history",
#         "Monuments and memorials",
#         "U.S. history",
#         "Veterans' organizations and recognition"
#     ],
#     "subjects_top_term": "Armed forces and national security",
#     "summary": {
#         "as": "Public Law",
#         "date": "2018-05-08T03:59:59Z",
#         "text": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act This bill authorizes the Pacific Historic Parks to establish and maintain a commemorative display to honor the members of the U.S. Armed Forces and Allies who served in the Pacific Theater during World War II.\n\nFederal funds may not be used to design, procure, prepare, install, or maintain the commemorative display, but the National Park Service may accept and expend contributions of nonfederal funds and resources for such purposes."
#     },
#     "titles": [
#         {
#             "as": "introduced",
#             "is_for_portion": false,
#             "title": "To authorize Pacific Historic Parks to establish a commemorative display to honor members of the United States Armed Forces who served in the Pacific Theater of World War II, and for other purposes.",
#             "type": "official"
#         },
#         {
#             "as": "enacted",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "passed senate",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "passed house",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "passed house",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. Joe Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "reported to senate",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "reported to senate",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. Joe Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "reported to house",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "reported to house",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. Joe Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "introduced",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": "introduced",
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. Joe Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "short"
#         },
#         {
#             "as": null,
#             "is_for_portion": false,
#             "title": "Admiral Lloyd R. \"Joe\" Vasey Pacific War Commemorative Display Establishment Act",
#             "type": "display"
#         }
#     ],
#     "updated_at": "2019-11-15T21:48:57Z",
#     "url": "https://www.govinfo.gov/bulkdata/BILLSTATUS/115/hr/BILLSTATUS-115hr4300.xml"
# }

# %%
# Out:
# Empty DataFrame
# Columns: [congress, bill_number, url]
# Index: []

# %%
bills_115_data = []
for bill_path in passed_bills:
    
    # there's a data.json file in every bill_path
    file_name = f'{ bill_path }/data.json'
    
    # read the json
    with open(file_name) as f:
        bill_json = json.load(f)
        bill_number = bill_json['number']
        bill_url = f'https://www.congress.gov/bill/115th-congress/house-bill/{ bill_number }/text?r=1&s=2'
        bills_115_data.append({
            'congress': 115,
            'bill_number': bill_number,
            'url': bill_url
        })
        
bills_115 = pd.DataFrame(bills_115_data)

# %%
bills_115
# Out:
#      congress bill_number                                                url
# 0         115        4300  https://www.congress.gov/bill/115th-congress/h...
# 1         115        7327  https://www.congress.gov/bill/115th-congress/h...
# 2         115        7318  https://www.congress.gov/bill/115th-congress/h...
# 3         115         754  https://www.congress.gov/bill/115th-congress/h...
# 4         115        3122  https://www.congress.gov/bill/115th-congress/h...
# ..        ...         ...                                                ...
# 279       115        6414  https://www.congress.gov/bill/115th-congress/h...
# 280       115        2611  https://www.congress.gov/bill/115th-congress/h...
# 281       115        6621  https://www.congress.gov/bill/115th-congress/h...
# 282       115        3996  https://www.congress.gov/bill/115th-congress/h...
# 283       115        3398  https://www.congress.gov/bill/115th-congress/h...
#
# [284 rows x 3 columns]
